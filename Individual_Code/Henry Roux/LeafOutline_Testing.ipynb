# %% [markdown]
# # Test "LeafOutline.py" file's function

# %%
from LeafOutline import leaf_outline

image, leaf_contour = leaf_outline("Sample Data/Original-leaf-black.png")


import cv2
import matplotlib.pyplot as plt

# Display the segmented image
plt.subplot(1, 2, 1)
plt.title('Original Image')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')
# Out:
# (-0.5, 1311.5, 1919.5, -0.5)

# %%
from LeafOutline import leaf_outline

image, leaf_contour = leaf_outline("Sample Data/Leaf 1.jpeg")

import matplotlib.pyplot as plt

# Display the segmented image
plt.subplot(1, 2, 1)
plt.title('Original Image')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')
# Out:
# (-0.5, 1279.5, 959.5, -0.5)

# %%
from LeafOutline import leaf_outline

image, leaf_contour = leaf_outline("Sample Data/Leaf-with-scars-1.png")

import matplotlib.pyplot as plt

# Display the segmented image
plt.subplot(1, 2, 1)
plt.title('Original Image')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')
# Out:
# (-0.5, 1311.5, 1919.5, -0.5)
