# %% [markdown]
# # Test output from "NewData.py"

# %%
from NewData import analyse_image

output = analyse_image("Leaf-with-scars.png")

output
# Out:
# {'lamina_area': 13.48,
#  'lamina_length': 16.3,
#  'lamina_width': 10.39,
#  'scar_count': 8,
#  'scar_area': 3.55,
#  'damagepercentage': 26.38}

# %%
from NewData import analyse_image

list = analyse_image("Leaf_1_Cube.png")

list
# Out:
# {'lamina_area': 2.32,
#  'lamina_length': 3.52,
#  'lamina_width': 4.15,
#  'scar_count': 28,
#  'scar_area': 0.32,
#  'damagepercentage': 13.63}
